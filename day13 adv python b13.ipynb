# %%
import numpy as np

import pandas as pd

from matplotlib import pyplot as plt

# %%
df =pd.read_csv('countries (2).csv')
df
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
us = df[df.country =='United States']

us
# Out:
#             country  year  population
# 1608  United States  1952   157553000
# 1609  United States  1957   171984000
# 1610  United States  1962   186538000
# 1611  United States  1967   198712000
# 1612  United States  1972   209896000
# 1613  United States  1977   220239000
# 1614  United States  1982   232187835
# 1615  United States  1987   242803533
# 1616  United States  1992   256894189
# 1617  United States  1997   272911760
# 1618  United States  2002   287675526
# 1619  United States  2007   301139947

# %%
ch = df[df.country =='China']

ch
# Out:
#     country  year  population
# 288   China  1952   556263527
# 289   China  1957   637408000
# 290   China  1962   665770000
# 291   China  1967   754550000
# 292   China  1972   862030000
# 293   China  1977   943455000
# 294   China  1982  1000281000
# 295   China  1987  1084035000
# 296   China  1992  1164970000
# 297   China  1997  1230075000
# 298   China  2002  1280400000
# 299   China  2007  1318683096

# %%
#COMPARISION OF CHINA & US

# %%
plt.plot(us.year,us.population)

plt.show()

# %%
plt.plot(us.year,us.population/10**6)

plt.show()

# %%
plt.plot(us.year,us.population/10**6)

plt.plot(ch.year,ch.population/10**6)

plt.title('comparision of us and china population')

plt.xlabel('year')

plt.ylabel('population')

plt.legend(['this is us data','this is china data'])

plt.show()

# %%
#comparision of india and germany population

# %%
ind = df[df.country == 'India']

ind
# Out:
#     country  year  population
# 696   India  1952   372000000
# 697   India  1957   409000000
# 698   India  1962   454000000
# 699   India  1967   506000000
# 700   India  1972   567000000
# 701   India  1977   634000000
# 702   India  1982   708000000
# 703   India  1987   788000000
# 704   India  1992   872000000
# 705   India  1997   959000000
# 706   India  2002  1034172547
# 707   India  2007  1110396331

# %%
GRM =df[df.country =='Germany']

GRM
# Out:
#      country  year  population
# 564  Germany  1952    69145952
# 565  Germany  1957    71019069
# 566  Germany  1962    73739117
# 567  Germany  1967    76368453
# 568  Germany  1972    78717088
# 569  Germany  1977    78160773
# 570  Germany  1982    78335266
# 571  Germany  1987    77718298
# 572  Germany  1992    80597764
# 573  Germany  1997    82011073
# 574  Germany  2002    82350671
# 575  Germany  2007    82400996

# %%
plt.plot(ind.year,ind.population/10**6)

plt.plot(GRM.year,GRM.population/10**6)

plt.title('comparison of india and germany population')

plt.xlabel('year')

plt.ylabel('population')

plt.legend(['this is india population','this is germany population'])

plt.show()

# %%
por =df[df.country == 'Portugal']

por
# Out:
#        country  year  population
# 1236  Portugal  1952     8526050
# 1237  Portugal  1957     8817650
# 1238  Portugal  1962     9019800
# 1239  Portugal  1967     9103000
# 1240  Portugal  1972     8970450
# 1241  Portugal  1977     9662600
# 1242  Portugal  1982     9859650
# 1243  Portugal  1987     9915289
# 1244  Portugal  1992     9927680
# 1245  Portugal  1997    10156415
# 1246  Portugal  2002    10433867
# 1247  Portugal  2007    10642836

# %%
pol = df[df.country == 'Poland']

pol
# Out:
#      country  year  population
# 1224  Poland  1952    25730551
# 1225  Poland  1957    28235346
# 1226  Poland  1962    30329617
# 1227  Poland  1967    31785378
# 1228  Poland  1972    33039545
# 1229  Poland  1977    34621254
# 1230  Poland  1982    36227381
# 1231  Poland  1987    37740710
# 1232  Poland  1992    38370697
# 1233  Poland  1997    38654957
# 1234  Poland  2002    38625976
# 1235  Poland  2007    38518241

# %%
plt.plot(por.year,por.population/10**6)

plt.plot(pol.year,pol.population/10**6)

plt.title('comparision of portugal and poland population')

plt.xlabel('year')

plt.ylabel('population')

plt.legend(['this is portugal data','this is poland data'])

plt.show()

# %%
aus =df[df.country == 'Australia']

aus
# Out:
#       country  year  population
# 60  Australia  1952     8691212
# 61  Australia  1957     9712569
# 62  Australia  1962    10794968
# 63  Australia  1967    11872264
# 64  Australia  1972    13177000
# 65  Australia  1977    14074100
# 66  Australia  1982    15184200
# 67  Australia  1987    16257249
# 68  Australia  1992    17481977
# 69  Australia  1997    18565243
# 70  Australia  2002    19546792
# 71  Australia  2007    20434176

# %%
uk = df[df.country == 'United Kingdom']

uk
# Out:
#              country  year  population
# 1596  United Kingdom  1952    50430000
# 1597  United Kingdom  1957    51430000
# 1598  United Kingdom  1962    53292000
# 1599  United Kingdom  1967    54959000
# 1600  United Kingdom  1972    56079000
# 1601  United Kingdom  1977    56179000
# 1602  United Kingdom  1982    56339704
# 1603  United Kingdom  1987    56981620
# 1604  United Kingdom  1992    57866349
# 1605  United Kingdom  1997    58808266
# 1606  United Kingdom  2002    59912431
# 1607  United Kingdom  2007    60776238

# %%
plt.plot(aus.year,aus.population/10**6)

plt.plot(uk.year,uk.population/10**6)

plt.title('comparision of australia and united kingdom population')

plt.xlabel('year')

plt.ylabel('population')

plt.legend(['this is australia population','this is united kingdom population'])

plt.show()

# %%
#working on data

# %%
datafile = pd.read_csv('sample_data (2).csv')

datafile
# Out:
#    column_a  column_b  column_c
# 0         1         1        10
# 1         2         4         8
# 2         3         9         6
# 3         4        16         4
# 4         5        25         2

# %%
type(datafile)
# Out:
# pandas.core.frame.DataFrame

# %%
plt.plot(datafile.column_a,datafile.column_b)

plt.show()

# %%
plt.plot(datafile.column_a,datafile.column_b)

plt.xlabel('test data')

plt.ylabel('experiment data')

plt.title('experiment data')

plt.legend(['this is test1sample','this is test2sample'])

plt.show()

# %%
plt.plot(datafile.column_a,datafile.column_b,'o')

plt.xlabel('test data')

plt.ylabel('experiment data')

plt.title('experiment data')

plt.legend(['this is test1sample','this is test2sample'])

plt.show()
